# %% [markdown]
# # **Setup**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from matplotlib import pyplot as plt

from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn import metrics

from sklearn.metrics import plot_roc_curve
from sklearn.decomposition import PCA
from matplotlib.pyplot import figure
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedShuffleSplit

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('preprocessed_spam_ham_phishing.csv')

# %% [markdown]
# **Remove phishing emails, only consider ham and spam:**

# %%
df = df[df['label'] != 2]
print(df.shape)
# Out:
# (75419, 95)

# %%
df['label'].value_counts()
# Out:
# 1    50199
# 0    25220
# Name: label, dtype: int64

# %%
df_Y = df['label']
df_X = df.drop('label', axis=1)

# %%
feature_list = df_X.columns

# %%
df_X.shape
# Out:
# (75419, 94)

# %% [markdown]
# **Apply a standard scaler to the full data set:**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(df_X)
df_X = scaler.transform(df_X)
df_X = pd.DataFrame(df_X, columns=feature_list)

# %% [markdown]
# # **Hyperparameter Tuning:**

# %% [markdown]
# Feature selection is done using PCA. PCA is a feature transformation process that builds new features from projections (linear combinations) of the old ones.

# %%
def get_best_params(pipe, param_grid_list):
    
  grid = GridSearchCV(pipe, param_grid=param_grid_list, cv=5, n_jobs=-1)

  # Passes the entire data set (it creates its own train and test set while doing CV)
  grid.fit(df_X, df_Y)

  return grid

# %% [markdown]
# **Use just a portion of the data to speed things up:**

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=0)

# %%
for train_index, test_index in sss.split(df_X, df_Y):
    df_X = df_X.iloc[test_index]
    df_Y = df_Y.iloc[test_index]

# %%
print(df_X.shape)
print(df_Y.shape)
# Out:
# (15084, 94)
# (15084,)

# %%
df_Y.value_counts()
# Out:
# 1    10040
# 0     5044
# Name: label, dtype: int64

# %% [markdown]
# **Random Forest:**

# %%
# %%time

pipe = Pipeline([("scale", StandardScaler()),
                ("reduce_dims", PCA()),
                ("rf", RandomForestClassifier())
                ])

param_grid_list = {'reduce_dims__n_components': [40], 
                  'rf__n_estimators': [100, 150, 200],
                  'rf__criterion': ['entropy', 'gini'],
                  'rf__min_samples_split': [2, 3, 4],
                  'rf__min_samples_leaf': [1, 2, 3],
                  'rf__max_features': ['auto', 'sqrt', 'log2']}

grid = get_best_params(pipe, param_grid_list)
rf_df = pd.DataFrame(grid.cv_results_)
print(grid.best_params_, '\n')
print(grid.best_estimator_)
rf_df[rf_df['rank_test_score'] <= 5].head(5)
# Out:
# {'reduce_dims__n_components': 40, 'rf__criterion': 'entropy', 'rf__max_features': 'auto', 'rf__min_samples_leaf': 1, 'rf__min_samples_split': 2, 'rf__n_estimators': 100}
#
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('reduce_dims', PCA(n_components=40)),
#                 ('rf', RandomForestClassifier(criterion='entropy'))])
# Wall time: 19min 11s
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        9.493832      0.197424         0.066022        0.003958
# 27       8.480269      0.149338         0.056250        0.002326
# 28      12.526362      0.073442         0.077992        0.001323
# 33       8.423822      0.136497         0.056753        0.002155
# 60       7.520952      0.186798         0.056355        0.000997
#
#    param_reduce_dims__n_components param_rf__criterion param_rf__max_features  \
# 0                               40             entropy                   auto
# 27                              40             entropy                   sqrt
# 28                              40             entropy                   sqrt
# 33                              40             entropy                   sqrt
# 60                              40             entropy                   log2
#
#    param_rf__min_samples_leaf param_rf__min_samples_split  \
# 0                           1                           2
# 27                          1                           2
# 28                          1                           2
# 33                          1                           4
# 60                          1                           4
#
#    param_rf__n_estimators                                             params  \
# 0                     100  {'reduce_dims__n_components': 40, 'rf__criteri...
# 27                    100  {'reduce_dims__n_components': 40, 'rf__criteri...
# 28                    150  {'reduce_dims__n_components': 40, 'rf__criteri...
# 33                    100  {'reduce_dims__n_components': 40, 'rf__criteri...
# 60                    100  {'reduce_dims__n_components': 40, 'rf__criteri...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.997680           0.995691           0.995691
# 27           0.998343           0.994697           0.995360
# 28           0.998343           0.995028           0.994697
# 33           0.997348           0.995360           0.995691
# 60           0.997348           0.995360           0.996023
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.997348           0.996353         0.996553        0.000828
# 27           0.997017           0.996021         0.996287        0.001282
# 28           0.997348           0.996021         0.996287        0.001381
# 33           0.997017           0.996021         0.996287        0.000767
# 60           0.997348           0.996021         0.996420        0.000796
#
#     rank_test_score
# 0                 1
# 27                3
# 28                3
# 33                3
# 60                2

# %% [markdown]
# **MLP:**

# %%
# %%time

pipe = Pipeline([("scale", StandardScaler()),
                ("reduce_dims", PCA()),
                ("mlp", MLPClassifier())
                ])

param_grid_list = {'reduce_dims__n_components': [40], 
                  'mlp__hidden_layer_sizes': [(20,), (20,20), (40,), (40,40)],
                   'mlp__activation': ['tanh', 'relu'],
                   'mlp__learning_rate': ['constant', 'adaptive'],
                   'mlp__solver': ['adam', 'sgd'],
                   'mlp__alpha': [0.0001, 0.001, 0.01]}

grid = get_best_params(pipe, param_grid_list)
res = pd.DataFrame(grid.cv_results_)
print(grid.best_params_, '\n')
print(grid.best_estimator_)
res[res['rank_test_score'] <= 5].head(5)
# Out:
# {'mlp__activation': 'tanh', 'mlp__alpha': 0.01, 'mlp__hidden_layer_sizes': (20,), 'mlp__learning_rate': 'constant', 'mlp__solver': 'adam', 'reduce_dims__n_components': 40}
#
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('reduce_dims', PCA(n_components=40)),
#                 ('mlp',
#                  MLPClassifier(activation='tanh', alpha=0.01,
#                                hidden_layer_sizes=(20,)))])
# Wall time: 9min 7s
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 10       6.918882      0.522170         0.015558        0.000797
# 24       6.625355      0.498495         0.015358        0.000796
# 32       5.771469      0.452068         0.012779        0.000407
# 40       7.111079      0.444515         0.014561        0.000488
# 42       6.141589      0.724573         0.015757        0.001322
#
#    param_mlp__activation param_mlp__alpha param_mlp__hidden_layer_sizes  \
# 10                  tanh           0.0001                         (40,)
# 24                  tanh            0.001                         (40,)
# 32                  tanh             0.01                         (20,)
# 40                  tanh             0.01                         (40,)
# 42                  tanh             0.01                         (40,)
#
#    param_mlp__learning_rate param_mlp__solver param_reduce_dims__n_components  \
# 10                 adaptive              adam                              40
# 24                 constant              adam                              40
# 32                 constant              adam                              40
# 40                 constant              adam                              40
# 42                 adaptive              adam                              40
#
#                                                params  split0_test_score  \
# 10  {'mlp__activation': 'tanh', 'mlp__alpha': 0.00...           0.996354
# 24  {'mlp__activation': 'tanh', 'mlp__alpha': 0.00...           0.996685
# 32  {'mlp__activation': 'tanh', 'mlp__alpha': 0.01...           0.997017
# 40  {'mlp__activation': 'tanh', 'mlp__alpha': 0.01...           0.997348
# 42  {'mlp__activation': 'tanh', 'mlp__alpha': 0.01...           0.997017
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 10           0.996023           0.997348           0.997680
# 24           0.996354           0.997017           0.997348
# 32           0.996685           0.996354           0.997348
# 40           0.995360           0.997348           0.996685
# 42           0.995691           0.997017           0.996685
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 10           0.996021         0.996685        0.000696                3
# 24           0.996353         0.996751        0.000387                2
# 32           0.996353         0.996751        0.000387                1
# 40           0.996353         0.996619        0.000738                4
# 42           0.996353         0.996553        0.000496                5

# %% [markdown]
# **Logistic Regression:**

# %%
# %%time

pipe = Pipeline([("scale", StandardScaler()),
                ("reduce_dims", PCA()),
                ("lr", LogisticRegression())
                ])

param_grid_list = {'reduce_dims__n_components': [40], 
                  'lr__max_iter': [500],
                  'lr__solver': ['newton-cg', 'lbfgs', 'sag', 'saga'],
                  'lr__fit_intercept': [True, False],
                  'lr__tol': [0.0001, 0.001],
                  'lr__penalty': ['l1', 'l2', 'elasticnet'],
                  'lr__C': [0.1, 1, 10]}

grid = get_best_params(pipe, param_grid_list)
print(grid.best_params_, '\n')
print(grid.best_estimator_)
lr_df = pd.DataFrame(grid.cv_results_)
lr_df[(lr_df['rank_test_score'] < 5)].head(5)
# Out:
# C:\Users\15066\AppData\Roaming\Python\Python38\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#  0.95246624 0.95220108 0.95419001 0.95392482 0.95399109 0.9539248
#  0.95399111 0.9539248  0.95392482 0.95399109        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.95259882 0.95246624 0.95392482 0.95412378 0.9540574  0.95379224
#  0.95399109 0.95385851 0.9539248  0.95392482        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.95518468 0.9549194  0.95491938 0.95485309 0.95511834 0.9547868
#  0.95505196 0.95491938 0.95498567 0.95485309        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.95465415 0.95538344 0.95491938 0.95491938 0.9547868  0.9547868
#  0.95485309 0.95485309 0.95491938 0.95478678        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.95445524 0.95452146 0.95465415 0.95485298 0.9547204  0.95438899
#  0.95458786 0.95432261 0.95452157 0.95458784        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.95445526 0.95445526 0.95452157 0.95452157 0.95419001 0.95419001
#  0.95445528 0.95438899 0.95445528 0.95432265        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.95505196 0.95505196 0.95518452 0.95511823 0.95505196 0.95498563
#  0.95525082 0.95511823 0.95491938 0.95525082        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.95498567 0.95518455 0.95498567 0.95511823 0.9553834  0.95531711
#  0.95511826 0.95485309 0.95531711 0.95558227        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.95472042 0.95511826 0.95458786 0.95452155 0.95438897 0.9547204
#  0.9553834  0.95491929 0.9545215  0.95511815        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.95458784 0.95458782 0.95485298 0.95498559 0.95458784 0.95491938
#  0.95438894 0.954853   0.95438897 0.95485311        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.95531713 0.95491936 0.95511823 0.9546542  0.95498567 0.95472049
#  0.95498565 0.95518455 0.95518455 0.95511826        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.95478678 0.95491938 0.95472049 0.95472049 0.95505194 0.95491936
#  0.95505194 0.95511823 0.95511826 0.95505194        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# {'lr__C': 1, 'lr__fit_intercept': False, 'lr__max_iter': 500, 'lr__penalty': 'l2', 'lr__solver': 'saga', 'lr__tol': 0.001, 'reduce_dims__n_components': 40}
#
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('reduce_dims', PCA(n_components=40)),
#                 ('lr',
#                  LogisticRegression(C=1, fit_intercept=False, max_iter=500,
#                                     solver='saga', tol=0.001))])
# Wall time: 2min 39s
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time param_lr__C  \
# 79        0.898731      0.213550         0.011569        0.001954         0.1
# 178       0.851902      0.070288         0.018750        0.005367           1
# 183       1.428609      0.237449         0.013165        0.007501           1
# 204       1.558232      0.162340         0.014364        0.003711          10
#
#     param_lr__fit_intercept param_lr__max_iter param_lr__penalty  \
# 79                    False                500                l1
# 178                   False                500                l2
# 183                   False                500                l2
# 204                    True                100                l2
#
#     param_lr__solver param_lr__tol param_reduce_dims__n_components  \
# 79              saga         0.001                              40
# 178            lbfgs        0.0001                              40
# 183             saga         0.001                              40
# 204              sag        0.0001                              40
#
#                                                 params  split0_test_score  \
# 79   {'lr__C': 0.1, 'lr__fit_intercept': False, 'lr...           0.949950
# 178  {'lr__C': 1, 'lr__fit_intercept': False, 'lr__...           0.948956
# 183  {'lr__C': 1, 'lr__fit_intercept': False, 'lr__...           0.949619
# 204  {'lr__C': 10, 'lr__fit_intercept': True, 'lr__...           0.950945
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 79            0.955585           0.954591           0.957574
# 178           0.955916           0.954922           0.958568
# 183           0.956248           0.954922           0.958568
# 204           0.955585           0.954259           0.957574
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 79            0.959218         0.955383        0.003152                2
# 178           0.958554         0.955383        0.003522                3
# 183           0.958554         0.955582        0.003292                1
# 204           0.958554         0.955383        0.002678                4

# %% [markdown]
# **SVM:**

# %%
# %%time

pipe = Pipeline([("scale", StandardScaler()),
                ("reduce_dims", PCA()),
                ("svc", SVC())
                ])

param_grid_list = {'reduce_dims__n_components': [40], 
                  'svc__C': [0.1, 1, 10],
                  'svc__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
                  'svc__degree': [3, 4, 5],
                  'svc__tol': [0.001, 0.0001, 0.01]}

grid = get_best_params(pipe, param_grid_list)
print(grid.best_params_, '\n')
print(grid.best_estimator_)
svm_df = pd.DataFrame(grid.cv_results_)
svm_df[(svm_df['rank_test_score'] < 5)].head(5)
# Out:
# {'reduce_dims__n_components': 40, 'svc__C': 10, 'svc__degree': 4, 'svc__kernel': 'rbf', 'svc__tol': 0.001}
#
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('reduce_dims', PCA(n_components=40)),
#                 ('svc', SVC(C=10, degree=4))])
# Wall time: 6min 33s
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 78       1.470495      0.070018         0.395293        0.018982
# 79       1.494684      0.057404         0.395252        0.008569
# 80       1.509290      0.044850         0.378294        0.009862
# 90       1.480424      0.057797         0.394944        0.030597
# 91       1.465797      0.045985         0.400036        0.027837
#
#    param_reduce_dims__n_components param_svc__C param_svc__degree  \
# 78                              40           10                 3
# 79                              40           10                 3
# 80                              40           10                 3
# 90                              40           10                 4
# 91                              40           10                 4
#
#    param_svc__kernel param_svc__tol  \
# 78               rbf          0.001
# 79               rbf         0.0001
# 80               rbf           0.01
# 90               rbf          0.001
# 91               rbf         0.0001
#
#                                                params  split0_test_score  \
# 78  {'reduce_dims__n_components': 40, 'svc__C': 10...           0.995028
# 79  {'reduce_dims__n_components': 40, 'svc__C': 10...           0.995028
# 80  {'reduce_dims__n_components': 40, 'svc__C': 10...           0.995028
# 90  {'reduce_dims__n_components': 40, 'svc__C': 10...           0.995028
# 91  {'reduce_dims__n_components': 40, 'svc__C': 10...           0.995028
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 78           0.993702           0.995028           0.997017
# 79           0.993702           0.995028           0.997017
# 80           0.993702           0.995028           0.997017
# 90           0.993702           0.995360           0.997017
# 91           0.993702           0.995360           0.997017
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 78           0.994695         0.995094        0.001077                3
# 79           0.994695         0.995094        0.001077                3
# 80           0.994695         0.995094        0.001077                3
# 90           0.994695         0.995160        0.001081                1
# 91           0.994695         0.995160        0.001081                1

# %% [markdown]
# **KNN:**

# %%
# %%time

pipe = Pipeline([("scale", StandardScaler()),
                ("reduce_dims", PCA()),
                ("knn", KNeighborsClassifier())
                ])

param_grid_list = {'reduce_dims__n_components': [40], 
                  'knn__n_neighbors': [1, 2, 5, 10, 20],
                  'knn__weights': ['uniform', 'distance'],
                  'knn__p': [1, 2],
                  'knn__algorithm': ['ball_tree', 'kd_tree', 'brute'],
                  'knn__leaf_size': [15, 30, 45]}

grid = get_best_params(pipe, param_grid_list)
knn_df = pd.DataFrame(grid.cv_results_)
print(grid.best_params_, '\n')
print(grid.best_estimator_)
knn_df[(knn_df['rank_test_score'] < 5)].head(5)
# Out:
# {'knn__algorithm': 'ball_tree', 'knn__leaf_size': 30, 'knn__n_neighbors': 1, 'knn__p': 1, 'knn__weights': 'uniform', 'reduce_dims__n_components': 40}
#
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('reduce_dims', PCA(n_components=40)),
#                 ('knn',
#                  KNeighborsClassifier(algorithm='ball_tree', n_neighbors=1,
#                                       p=1))])
# Wall time: 6min 26s
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 20       0.497887      0.016867         4.925350        0.167815
# 21       0.499345      0.015271         4.817770        0.185845
# 25       0.496105      0.017030         5.038324        0.168992
# 41       0.494241      0.013142         4.808166        0.187206
# 45       0.502106      0.016983         5.037473        0.161937
#
#    param_knn__algorithm param_knn__leaf_size param_knn__n_neighbors  \
# 20            ball_tree                   30                      1
# 21            ball_tree                   30                      1
# 25            ball_tree                   30                      2
# 41            ball_tree                   45                      1
# 45            ball_tree                   45                      2
#
#    param_knn__p param_knn__weights param_reduce_dims__n_components  \
# 20            1            uniform                              40
# 21            1           distance                              40
# 25            1           distance                              40
# 41            1           distance                              40
# 45            1           distance                              40
#
#                                                params  split0_test_score  \
# 20  {'knn__algorithm': 'ball_tree', 'knn__leaf_siz...           0.997017
# 21  {'knn__algorithm': 'ball_tree', 'knn__leaf_siz...           0.996685
# 25  {'knn__algorithm': 'ball_tree', 'knn__leaf_siz...           0.996685
# 41  {'knn__algorithm': 'ball_tree', 'knn__leaf_siz...           0.996685
# 45  {'knn__algorithm': 'ball_tree', 'knn__leaf_siz...           0.996685
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 20           0.994365           0.996354           0.997017
# 21           0.994365           0.996354           0.997017
# 25           0.994365           0.996354           0.997017
# 41           0.994365           0.996354           0.997017
# 45           0.994365           0.996354           0.997017
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 20           0.998342         0.996619        0.001299                1
# 21           0.998342         0.996553        0.001285                3
# 25           0.998342         0.996553        0.001285                3
# 41           0.998342         0.996553        0.001285                3
# 45           0.998342         0.996553        0.001285                3

# %% [markdown]
# **Decision Tree:**

# %%
# %%time

pipe = Pipeline([("scale", StandardScaler()),
                ("reduce_dims", PCA()),
                ("dt", DecisionTreeClassifier())
                ])

param_grid_list = {'reduce_dims__n_components': [40], 
                  'dt__criterion': ['entropy', 'gini'],
                  'dt__min_samples_split': [2, 3, 4],
                  'dt__min_samples_leaf': [1, 2, 3],
                  'dt__ccp_alpha': [0, 0.005, 0.01, 0.025, 0.05, 0.1]}

grid = get_best_params(pipe, param_grid_list)
print(grid.best_params_, '\n')
print(grid.best_estimator_)
dt_df = pd.DataFrame(grid.cv_results_)
dt_df[dt_df['rank_test_score'] <= 5].head(5)
# Out:
# {'dt__ccp_alpha': 0, 'dt__criterion': 'entropy', 'dt__min_samples_leaf': 1, 'dt__min_samples_split': 2, 'reduce_dims__n_components': 40}
#
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('reduce_dims', PCA(n_components=40)),
#                 ('dt',
#                  DecisionTreeClassifier(ccp_alpha=0, criterion='entropy'))])
# Wall time: 1min 6s
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        1.178051      0.018695         0.010772        0.002129
# 1        1.160915      0.034575         0.010772        0.002309
# 2        1.143390      0.019874         0.012567        0.002646
# 3        1.094682      0.023315         0.009376        0.001352
# 11       1.068743      0.200625         0.010373        0.001017
#
#    param_dt__ccp_alpha param_dt__criterion param_dt__min_samples_leaf  \
# 0                    0             entropy                          1
# 1                    0             entropy                          1
# 2                    0             entropy                          1
# 3                    0             entropy                          2
# 11                   0                gini                          1
#
#    param_dt__min_samples_split param_reduce_dims__n_components  \
# 0                            2                              40
# 1                            3                              40
# 2                            4                              40
# 3                            2                              40
# 11                           4                              40
#
#                                                params  split0_test_score  \
# 0   {'dt__ccp_alpha': 0, 'dt__criterion': 'entropy...           0.993039
# 1   {'dt__ccp_alpha': 0, 'dt__criterion': 'entropy...           0.989062
# 2   {'dt__ccp_alpha': 0, 'dt__criterion': 'entropy...           0.992377
# 3   {'dt__ccp_alpha': 0, 'dt__criterion': 'entropy...           0.992045
# 11  {'dt__ccp_alpha': 0, 'dt__criterion': 'gini', ...           0.990719
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.989062           0.991051           0.990719
# 1            0.988399           0.989725           0.992708
# 2            0.989393           0.990388           0.992045
# 3            0.987073           0.990388           0.989393
# 11           0.987736           0.991714           0.991714
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.990385         0.990851        0.001286                1
# 1            0.990053         0.989989        0.001473                3
# 2            0.989721         0.990785        0.001212                2
# 3            0.987732         0.989326        0.001797                4
# 11           0.984748         0.989326        0.002714                5

# %% [markdown]
# **Naive Bayes (Gaussian):**

# %%
# %%time

pipe = Pipeline([("scale", StandardScaler()),
                ("reduce_dims", PCA()),
                ("gnb", GaussianNB())
                ])

param_grid_list = {'reduce_dims__n_components': [40], 
                  'gnb__var_smoothing': [1E-9, 1E-10, 1E-8]}

grid = get_best_params(pipe, param_grid_list)
print(grid.best_params_, '\n')
print(grid.best_estimator_)
gnb_df = pd.DataFrame(grid.cv_results_)
gnb_df[gnb_df['rank_test_score'] <= 5].head(5)
# Out:
# {'gnb__var_smoothing': 1e-08, 'reduce_dims__n_components': 40}
#
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('reduce_dims', PCA(n_components=40)),
#                 ('gnb', GaussianNB(var_smoothing=1e-08))])
# Wall time: 1.57 s
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.591020      0.006870         0.016755        0.001163
# 1       0.573466      0.020167         0.017952        0.003154
# 2       0.553918      0.007068         0.011370        0.003128
#
#   param_gnb__var_smoothing param_reduce_dims__n_components  \
# 0                    1e-09                              40
# 1                    1e-10                              40
# 2                    1e-08                              40
#
#                                               params  split0_test_score  \
# 0  {'gnb__var_smoothing': 1e-09, 'reduce_dims__n_...           0.876036
# 1  {'gnb__var_smoothing': 1e-10, 'reduce_dims__n_...           0.875704
# 2  {'gnb__var_smoothing': 1e-08, 'reduce_dims__n_...           0.876036
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.874710           0.880013           0.876699           0.875000
# 1           0.875373           0.880013           0.876699           0.874668
# 2           0.875041           0.879682           0.877030           0.875000
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.876492        0.001900                2
# 1         0.876492        0.001878                3
# 2         0.876558        0.001731                1

# %% [markdown]
# **AdaBoost:**

# %%
# %%time

pipe = Pipeline([("scale", StandardScaler()),
                ("reduce_dims", PCA()),
                ("ab", AdaBoostClassifier())
                ])

param_grid_list = {'reduce_dims__n_components': [40], 
                  'ab__n_estimators': [50, 100, 150, 200],
                  'ab__learning_rate': [0.95, 1, 1.05, 1.25, 1.5, 1.75, 2],
                  'ab__algorithm': ['SAMME', 'SAMME.R']}

grid = get_best_params(pipe, param_grid_list)
print(grid.best_params_, '\n')
print(grid.best_estimator_)
ab_df = pd.DataFrame(grid.cv_results_)
ab_df[ab_df['rank_test_score'] <= 5].head(5)
# Out:
# {'ab__algorithm': 'SAMME.R', 'ab__learning_rate': 1.5, 'ab__n_estimators': 200, 'reduce_dims__n_components': 40}
#
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('reduce_dims', PCA(n_components=40)),
#                 ('ab',
#                  AdaBoostClassifier(learning_rate=1.5, n_estimators=200))])
# Wall time: 6min 34s
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 31      16.931281      0.069902         0.203656        0.010159
# 35      16.977513      0.096812         0.206449        0.018118
# 39      16.877358      0.080950         0.196779        0.002273
# 43      16.945272      0.071996         0.205051        0.008500
# 47      16.945281      0.111864         0.207045        0.019042
#
#    param_ab__algorithm param_ab__learning_rate param_ab__n_estimators  \
# 31             SAMME.R                    0.95                    200
# 35             SAMME.R                       1                    200
# 39             SAMME.R                    1.05                    200
# 43             SAMME.R                    1.25                    200
# 47             SAMME.R                     1.5                    200
#
#    param_reduce_dims__n_components  \
# 31                              40
# 35                              40
# 39                              40
# 43                              40
# 47                              40
#
#                                                params  split0_test_score  \
# 31  {'ab__algorithm': 'SAMME.R', 'ab__learning_rat...           0.989393
# 35  {'ab__algorithm': 'SAMME.R', 'ab__learning_rat...           0.989062
# 39  {'ab__algorithm': 'SAMME.R', 'ab__learning_rat...           0.990056
# 43  {'ab__algorithm': 'SAMME.R', 'ab__learning_rat...           0.992708
# 47  {'ab__algorithm': 'SAMME.R', 'ab__learning_rat...           0.992708
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 31           0.990056           0.991051           0.990719
# 35           0.988731           0.991051           0.992377
# 39           0.989725           0.990388           0.991714
# 43           0.990719           0.991714           0.994697
# 47           0.992045           0.992377           0.992708
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 31           0.993700         0.990984        0.001473                3
# 35           0.993369         0.990918        0.001810                4
# 39           0.992042         0.990785        0.000923                5
# 43           0.991379         0.992243        0.001385                2
# 47           0.992706         0.992509        0.000265                1

# %% [markdown]
# **GradientBoostingClassifier:**

# %%
# %%time

pipe = Pipeline([("scale", StandardScaler()),
                ("reduce_dims", PCA()),
                ("gbc", GradientBoostingClassifier())
                ])

param_grid_list = {'reduce_dims__n_components': [40],
                   'gbc__max_features': ['auto', 'sqrt', 'log2'],
                   'gbc__learning_rate': [0.05, 0.1, 0.2, 0.25, 0.30, 0.35, 0.40, 0.5, 0.6, 0.7, 0.9],
                   'gbc__n_estimators': [100, 200]
                  }

grid = get_best_params(pipe, param_grid_list)
print(grid.best_params_, '\n')
print(grid.best_estimator_)
gbc_df = pd.DataFrame(grid.cv_results_)
gbc_df[gbc_df['rank_test_score'] <= 5].head(5)
# Out:
# {'gbc__learning_rate': 0.4, 'gbc__max_features': 'log2', 'gbc__n_estimators': 200, 'reduce_dims__n_components': 40}
#
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('reduce_dims', PCA(n_components=40)),
#                 ('gbc',
#                  GradientBoostingClassifier(learning_rate=0.4,
#                                             max_features='log2',
#                                             n_estimators=200))])
# Wall time: 9min 27s
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 27       6.970852      0.254637         0.023737        0.005101
# 29       6.116166      0.174998         0.023937        0.002600
# 41       6.745234      0.450648         0.024336        0.003000
# 45       6.831288      0.056587         0.021753        0.000735
# 53       5.883035      0.023411         0.021343        0.000489
#
#    param_gbc__learning_rate param_gbc__max_features param_gbc__n_estimators  \
# 27                      0.3                    sqrt                     200
# 29                      0.3                    log2                     200
# 41                      0.4                    log2                     200
# 45                      0.5                    sqrt                     200
# 53                      0.6                    log2                     200
#
#    param_reduce_dims__n_components  \
# 27                              40
# 29                              40
# 41                              40
# 45                              40
# 53                              40
#
#                                                params  split0_test_score  \
# 27  {'gbc__learning_rate': 0.3, 'gbc__max_features...           0.996354
# 29  {'gbc__learning_rate': 0.3, 'gbc__max_features...           0.996023
# 41  {'gbc__learning_rate': 0.4, 'gbc__max_features...           0.996685
# 45  {'gbc__learning_rate': 0.5, 'gbc__max_features...           0.994697
# 53  {'gbc__learning_rate': 0.6, 'gbc__max_features...           0.996023
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 27           0.995028           0.995691           0.998011
# 29           0.995360           0.996023           0.996354
# 41           0.995360           0.995691           0.997348
# 45           0.993702           0.996354           0.998674
# 53           0.995360           0.995691           0.996354
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 27           0.995358         0.996089        0.001057                2
# 29           0.995358         0.995823        0.000398                5
# 41           0.996021         0.996221        0.000714                1
# 45           0.995690         0.995823        0.001685                4
# 53           0.996021         0.995890        0.000338                3
