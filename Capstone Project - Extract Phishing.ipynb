# %%
import pandas as pd
import shutil
from os import listdir, mkdir, path
from pathlib import Path
import sys
from email.parser import HeaderParser
import collections
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import time
from collections import Counter

# %%
parser = HeaderParser()
columns = ['received1',
'received2',
'received3',
'received4',
'received5',
'received6',
'received7',
'received8',
'hops',
'subject',
'date',
'message-id',
'from',
'return-path',
'to',
'content-type',
'mime-version',
'x-mailer',
'content-transfer-encoding',
'x-mimeole',
'x-priority',
'list-id',
'lines',
'x-virus-scanned',
'status',
'content-length',
'precedence',
'delivered-to',
'list-unsubscribe',
'list-subscribe',
'list-post',
'list-help',
'x-msmail-priority',
'x-spam-status',
'sender',
'errors-to',
'x-beenthere',
'list-archive',
'reply-to',
'x-mailman-version',
'x-miltered',
'x-uuid',
'x-virus-status',
'x-spam-level',
'x-spam-checker-version',
'references',
'in-reply-to',
'user-agent',
'thread-index',
'cc',
'received-spf',
'x-original-to',
'content-disposition',
'mailing-list',
'x-spam-check-by',
'domainkey-signature',
'importance',
'x-mailing-list',
'label']

list_of_rows = []


def addEmailsToDict(email_list):
    global parser, list_of_rows
    
    # The label for phishing, set to '2'
    label = 2
    
    
    # Read the full email content
    for email in email_list:
        row_dict = {}
        
        # Parse the email content
        h = parser.parsestr(email)

        # Parse recieved field
        received_list = h.get_all('received')
        hops = 0
        if received_list is not None:
            hops = len(received_list)
            col_name_recieved = 'received'

            for inx, received_field in enumerate(received_list):
                col = col_name_recieved + str(inx+1)
                row_dict[col] = received_field


        # Make everything lowercase to avoid issues
        features_lower_case = [x.lower() for x in h.keys()]

        # Parse everything else
        new_row = dict(zip(features_lower_case, h.values()))
        new_row['hops'] = hops


        for key,value in new_row.items():
            if key in columns:
                row_dict['label'] = label
                row_dict[key] = value


        list_of_rows.append(row_dict)

def main():
    global list_of_rows

    file_path = 'Phishing Dataset/phishing-2017.txt'
    
    # Read the full email content
    emailStr = ''
    try:
        with open(file_path, encoding='latin_1') as emailFile:
            for line in emailFile:
                emailStr += line
    except UnicodeDecodeError:
        print('Unicode Error!')
    
    email_list = emailStr.split('\nFrom jose@monkey.org')
    #print(email_list[1])
    
    addEmailsToDict(email_list)
    
    # Create the dataframe
    df = pd.DataFrame(list_of_rows)
    
    final_columns = []
    for col in columns:
        if col in df.columns:
            final_columns.append(col)
            
    df = df[final_columns]
    
    # Output the dataframe to a .csv file
    df.to_csv('phishing_out_2017V2.csv', index=False)

if __name__ == '__main__':
    main()

# %% [markdown]
# **Show the most common header fields:**

# %%
parser = HeaderParser()
dict_header_features = {}
total_emails = 0


def addEmailsToDict(email_list):
    global parser, dict_header_features, total_emails
    
    # Read the full email content
    for email in email_list:
        
        total_emails += 1
        h = parser.parsestr(email)
        features_lower_case = [x.lower() for x in h.keys()]
        features_dict = Counter(features_lower_case)

        for k,v in features_dict.items():
            if k in dict_header_features:
                dict_header_features[k] += 1
            else:
                dict_header_features[k] = 1

                
def main():
    global dict_header_features, total_emails
        
    file_path = 'Phishing Dataset/phishing-2017.txt'
    
    # Read the full email content
    emailStr = ''
    try:
        with open(file_path, encoding='latin_1') as emailFile:
            for line in emailFile:
                emailStr += line
    except UnicodeDecodeError:
        print('Unicode Error!')
    
    email_list = emailStr.split('\nFrom jose@monkey.org')
    #print(email_list[1])
    
    addEmailsToDict(email_list)
    
    df = pd.DataFrame(columns=columns)
        
    dict_header_features = sorted(dict_header_features.items(), key=lambda x:x[1], reverse=True)

    for v in dict_header_features:
        print(v)
        
    unzipped = list(zip(*dict_header_features))
    lab = unzipped[0]
    val = unzipped[1]
    print("TOTAL EMAIL COUNT:", total_emails)
    val = [x/total_emails for x in val]
    figure(figsize=(15, 6))
    axes = plt.gca()
    axes.set_ylim([0,1])
    plt.xticks(rotation='vertical')
    plt.ylabel('Percent of total emails')
    plt.bar(lab[0:20], val[0:20], width=0.25)
    plt.grid()
    #plt.savefig('most_common_header_features_phish1.png', bbox_inches="tight")
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# ('date', 324)
# ('from', 324)
# ('subject', 324)
# ('return-path', 323)
# ('delivered-to', 323)
# ('x-fda', 323)
# ('x-spam-summary', 323)
# ('x-he-tag', 323)
# ('x-filterd-recvd-size', 323)
# ('received', 323)
# ('content-type', 323)
# ('status', 322)
# ('x-status', 321)
# ('x-keywords', 321)
# ('x-uid', 321)
# ('mime-version', 320)
# ('to', 304)
# ('message-id', 252)
# ('reply-to', 64)
# ('x-antiabuse', 57)
# ('x-get-message-sender-via', 56)
# ('content-transfer-encoding', 56)
# ('x-authenticated-sender', 55)
# ('x-priority', 52)
# ('x-originating-ip', 47)
# ('x-source', 43)
# ('x-source-args', 43)
# ('x-source-dir', 43)
# ('dkim-signature', 42)
# ('x-mailer', 41)
# ('thread-index', 40)
# ('thread-topic', 39)
# ('x-ms-has-attach', 36)
# ('x-ms-tnef-correlator', 36)
# ('accept-language', 35)
# ('content-language', 35)
# ('x-virus-scanned', 27)
# ('authentication-results', 27)
# ('x-msmail-priority', 24)
# ('x-php-originating-script', 24)
# ('x-originalarrivaltime', 19)
# ('references', 18)
# ('in-reply-to', 16)
# ('received-spf', 15)
# ('x-forefront-antispam-report', 13)
# ('x-microsoft-exchange-diagnostics', 13)
# ('x-ms-office365-filtering-correlation-id', 13)
# ('x-microsoft-antispam', 13)
# ('x-microsoft-antispam-prvs', 13)
# ('x-exchange-antispam-report-test', 13)
# ('x-exchange-antispam-report-cfa-test', 13)
# ('x-forefront-prvs', 13)
# ('spamdiagnosticoutput', 13)
# ('x-originatororg', 13)
# ('x-ms-exchange-crosstenant-originalarrivaltime', 13)
# ('x-ms-exchange-crosstenant-fromentityheader', 13)
# ('x-ms-exchange-transport-crosstenantheadersstamped', 13)
# ('x-ironport-av', 11)
# ('x-mimeole', 11)
# ('x-spam-status', 10)
# ('x-google-dkim-signature', 10)
# ('x-gm-message-state', 10)
# ('x-received', 10)
# ('x-ms-publictraffictype', 10)
# ('x-outgoing-spam-status', 9)
# ('x-relaying-domain', 9)
# ('x-ms-exchange-crosstenant-id', 9)
# ('x-php-script', 8)
# ('x-cm-score', 8)
# ('x-antivirus', 7)
# ('x-ct-class', 7)
# ('x-ct-score', 7)
# ('x-ct-refid', 7)
# ('x-ct-spam', 7)
# ('x-authority-analysis', 7)
# ('x-ms-traffictypediagnostic', 7)
# ('importance', 6)
# ('x-antivirus-status', 6)
# ('sender', 6)
# ('x-clientproxiedby', 6)
# ('x-ironport-anti-spam-filtered', 5)
# ('x-ironport-anti-spam-result', 5)
# ('x-spam-flag', 5)
# ('x-spam-level', 5)
# ('x-spam-checker-version', 5)
# ('x-eopattributedmessage', 5)
# ('x-ms-exchange-crosstenant-originalattributedtenantconnectingip', 5)
# ('priority', 5)
# ('x-ipas-result', 4)
# ('acceptlanguage', 4)
# ('x-proofpoint-virus-version', 4)
# ('x-virus-status', 4)
# ('x-no-relay', 4)
# ('x-ms-exchange-transport-fromentityheader', 4)
# ('x-sender', 4)
# ('x-yahoo-newman-property', 3)
# ('x-yahoo-newman-id', 3)
# ('x-ymail-osg', 3)
# ('sensitivity', 3)
# ('x-recommended-action', 3)
# ('x-filter-id', 3)
# ('x-report-abuse-to', 3)
# ('user-agent', 3)
# ('x-tm-as-product-ver', 3)
# ('x-tm-as-result', 3)
# ('x-spam-processed', 2)
# ('x-mdremoteip', 2)
# ('x-return-path', 2)
# ('x-envelope-from', 2)
# ('x-mdaemon-deliver-to', 2)
# ('content-length', 2)
# ('x-spam-score', 2)
# ('x-vpm-host', 2)
# ('x-vpm-group-id', 2)
# ('x-vpm-msg-id', 2)
# ('x-vpm-enc-regime', 2)
# ('x-vpm-is-hybrid', 2)
# ('x-proofpoint-spam-reason', 2)
# ('x-scanned-by', 2)
# ('x-netcomp-mailscanner-information', 2)
# ('x-netcomp-mailscanner-id', 2)
# ('x-netcomp-mailscanner', 2)
# ('x-netcomp-mailscanner-spamscore', 2)
# ('x-netcomp-mailscanner-from', 2)
# ('dkim-filter', 2)
# ('x-spamexperts-domain', 2)
# ('x-spamexperts-username', 2)
# ('x-spamexperts-outgoing-class', 2)
# ('x-spamexperts-outgoing-evidence', 2)
# ('spamdiagnosticmetadata', 2)
# ('x-brightmail-tracker', 2)
# ('return-receipt-to', 2)
# ('x-php-filename', 2)
# ('x-tm-as-user-approved-sender', 2)
# ('x-tm-as-user-blocked-sender', 2)
# ('x-sa-exim-connect-ip', 2)
# ('x-sa-exim-mail-from', 2)
# ('x-sa-exim-version', 2)
# ('x-sa-exim-scanned', 2)
# ('x-ms-office365-filtering-ht', 2)
# ('domainkey-signature', 2)
# ('x-mailgun-sending-ip', 2)
# ('x-mailgun-sid', 2)
# ('x-imap', 1)
# ('x-mimetrack', 1)
# ('x-cyberoam-smtpxy-version', 1)
# ('x-cyberoam-av-policy', 1)
# ('ironport-phdr', 1)
# ('x-pmwin-version', 1)
# ('content-class', 1)
# ('x-msw-jemd-spam', 1)
# ('x-msw-jemd-refid', 1)
# ('x-rc-from', 1)
# ('x-dlp-outbound', 1)
# ('x-mag-outbound', 1)
# ('x-modus-blacklist', 1)
# ('x-modus-trusted', 1)
# ('x-modus-spam-version', 1)
# ('x-modus-audit', 1)
# ('x-spam-ctch-refid', 1)
# ('x-exclaimer-md-config', 1)
# ('x-id', 1)
# ('x-toi-msgid', 1)
# ('x_cmae_category', 1)
# ('x-cnfs-analysis', 1)
# ('x-authed-username', 1)
# ('x-mb-message-source', 1)
# ('x-mb-message-type', 1)
# ('x-aol-global-disposition', 1)
# ('x-aol-reroute', 1)
# ('x-aol-sid', 1)
# ('x-suspect-keyword', 1)
# ('x-mailer-lid', 1)
# ('list-unsubscribe', 1)
# ('x-mailer-recptid', 1)
# ('x-mailer-sid', 1)
# ('x-mailer-sent-by', 1)
# ('x-hermes-message-id', 1)
# ('x-hm-ut', 1)
# ('content-disposition', 1)
# ('x-bayes-prob', 1)
# ('x-canit-geo', 1)
# ('x-canitpro-stream', 1)
# ('x-canit-stats-id', 1)
# ('x-auditid', 1)
# ('x-microsoft-exchange-diagnostics-untrusted', 1)
# ('x-microsoft-antispam-untrusted', 1)
# ('x-forefront-antispam-report-untrusted', 1)
# ('x-ms-exchange-transport-crosstenantheadersstripped', 1)
# ('x-dkimresult-test', 1)
# ('disposition-notification-to', 1)
# ('x-nai-spam-flag', 1)
# ('x-nai-spam-level', 1)
# ('x-nai-spam-threshold', 1)
# ('x-nai-spam-score', 1)
# ('x-nai-spam-version', 1)
# ('x-disclaimer', 1)
# ('x-imss-scan-details', 1)
# ('x-tmase-matchedrid', 1)
# ('x-imss-dkim-white-list', 1)
# ('x-ait-server-origin', 1)
# ('x-ait-path-origin', 1)
# ('x-ait-rev', 1)
# ('x-env-sender', 1)
# ('x-msg-ref', 1)
# ('x-starscan-received', 1)
# ('x-starscan-version', 1)
# ('x-viruschecked', 1)
# ('x-marr-info', 1)
# ('x-auth-id', 1)
# ('x-kerio-anti-spam', 1)
# ('x-footer', 1)
# ('x-antivirus-mydomain-mail-from', 1)
# ('x-antivirus-mydomain', 1)
# ('x-antivirus-mydomain-message-id', 1)
# ('list-id', 1)
# ('x-csa-complaints', 1)
# ('x-job', 1)
# ('x-proofpoint-spam-details', 1)
# ('bcc', 1)
# ('x-authuser', 1)
# ('x-hospedandoantispam-domain', 1)
# ('x-hospedandoantispam-username', 1)
# ('x-hospedandoantispam-outgoing-class', 1)
# ('x-hospedandoantispam-outgoing-evidence', 1)
# ('x-dnsrbl', 1)
# ('x-mail', 1)
# ('organization', 1)
# ('x-xm-spf', 1)
# ('x-spam-report', 1)
# ('x-spam-dcc', 1)
# ('x-spam-combo', 1)
# ('x-spam-relay-country', 1)
# ('x-spam-timing', 1)
# ('x-disclaimer-applied', 1)
# ('x-7fa49cb5', 1)
# ('x-mailru-sender', 1)
# ('x-mras', 1)
# ('x-spam', 1)
# ('x-kse-serverinfo', 1)
# ('x-kse-antispam-interceptor-info', 1)
# ('x-kse-antivirus-interceptor-info', 1)
# ('x-kse-antivirus-info', 1)
# ('x-kse-attachment-filter-scan-result', 1)
# ('x-kse-dlp-scaninfo', 1)
# ('x-google-smtp-source', 1)
# ('x-mdav-processed', 1)
# ('x-mdhelo', 1)
# ('x-mdarrival-date', 1)
# ('x-cav-result', 1)
# ('x-proofpoint-virus-details', 1)
# TOTAL EMAIL COUNT: 324
